# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("salesdaily.csv")
df
# Out:
#            datum  M01AB   M01AE  N02BA  N02BE  N05B  N05C   R03   R06  Year  \
# 0     01-02-2014   0.00   3.670   3.40  32.40   7.0   0.0   0.0  2.00  2014
# 1     01-03-2014   8.00   4.000   4.40  50.60  16.0   0.0  20.0  4.00  2014
# 2     01-04-2014   2.00   1.000   6.50  61.85  10.0   0.0   9.0  1.00  2014
# 3     01-05-2014   4.00   3.000   7.00  41.10   8.0   0.0   3.0  0.00  2014
# 4     01-06-2014   5.00   1.000   4.50  21.70  16.0   2.0   6.0  2.00  2014
# ...          ...    ...     ...    ...    ...   ...   ...   ...   ...   ...
# 2101  10-04-2019   7.34   5.683   2.25  22.45  13.0   0.0   1.0  1.00  2019
# 2102  10-05-2019   3.84   5.010   6.00  25.40   7.0   0.0   0.0  0.33  2019
# 2103  10-06-2019   4.00  11.690   2.00  34.60   6.0   0.0   5.0  4.20  2019
# 2104  10-07-2019   7.34   4.507   3.00  50.80   6.0   0.0  10.0  1.00  2019
# 2105  10-08-2019   0.33   1.730   0.50  44.30  20.0   2.0   2.0  0.00  2019
#
#       Month  Hour Weekday Name
# 0         1   248     Thursday
# 1         1   276       Friday
# 2         1   276     Saturday
# 3         1   276       Sunday
# 4         1   276       Monday
# ...     ...   ...          ...
# 2101     10   276       Friday
# 2102     10   276     Saturday
# 2103     10   276       Sunday
# 2104     10   276       Monday
# 2105     10   190      Tuesday
#
# [2106 rows x 13 columns]

# %%
df_new = df.melt(id_vars=['datum', 'Year', 'Month', 'Hour', 'Weekday Name'], var_name='Drug', value_name='Quantity')
df_new.head()
# Out:
#         datum  Year  Month  Hour Weekday Name   Drug  Quantity
# 0  01-02-2014  2014      1   248     Thursday  M01AB       0.0
# 1  01-03-2014  2014      1   276       Friday  M01AB       8.0
# 2  01-04-2014  2014      1   276     Saturday  M01AB       2.0
# 3  01-05-2014  2014      1   276       Sunday  M01AB       4.0
# 4  01-06-2014  2014      1   276       Monday  M01AB       5.0

# %%
df_new.shape
# Out:
# (16848, 7)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_new['Weekday Name'] = le.fit_transform(df_new['Weekday Name'])
df_new['Drug'] = le.fit_transform(df_new['Drug'])
df_new
# Out:
#             datum  Year  Month  Hour  Weekday Name  Drug  Quantity
# 0      01-02-2014  2014      1   248             4     0      0.00
# 1      01-03-2014  2014      1   276             0     0      8.00
# 2      01-04-2014  2014      1   276             2     0      2.00
# 3      01-05-2014  2014      1   276             3     0      4.00
# 4      01-06-2014  2014      1   276             1     0      5.00
# ...           ...   ...    ...   ...           ...   ...       ...
# 16843  10-04-2019  2019     10   276             0     7      1.00
# 16844  10-05-2019  2019     10   276             2     7      0.33
# 16845  10-06-2019  2019     10   276             3     7      4.20
# 16846  10-07-2019  2019     10   276             1     7      1.00
# 16847  10-08-2019  2019     10   190             5     7      0.00
#
# [16848 rows x 7 columns]

# %%
train = df_new[df_new['Year'] < 2019]
test = df_new[df_new['Year'] >= 2019]

print(train.shape)
print(test.shape)
# Out:
# (14600, 7)
# (2248, 7)

# %%
X_train = train.drop(['Hour','Quantity','datum'],axis = 1)
y_train = train['Quantity']

X_test = test.drop(['Hour','Quantity','datum'],axis = 1)
y_test = test['Quantity']

# %%
X_train
# Out:
#        Year  Month  Weekday Name  Drug
# 0      2014      1             4     0
# 1      2014      1             0     0
# 2      2014      1             2     0
# 3      2014      1             3     0
# 4      2014      1             1     0
# ...     ...    ...           ...   ...
# 16562  2018     12             4     7
# 16563  2018     12             0     7
# 16564  2018     12             2     7
# 16565  2018     12             3     7
# 16566  2018     12             1     7
#
# [14600 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor(max_depth=2, random_state=0)
reg_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
from sklearn.metrics import mean_squared_error
rf_pred = reg_rf.predict(X_test)
mse = mean_squared_error(y_test,rf_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(8.546336651758923)

# %%
import xgboost as xgb
reg = xgb.XGBRegressor(n_estimators = 1000,early_stopping_rounds = 50, learning_rate = 0.005)
reg.fit(X_train,y_train,
       eval_set = [(X_train,y_train),(X_test,y_test)],
       verbose = 10)
y_pred =reg.predict(X_test)
rmse = np.sqrt(mse)
print(rmse)
# Out:
# [0]	validation_0-rmse:10.89225	validation_1-rmse:10.62390
# [10]	validation_0-rmse:10.51182	validation_1-rmse:10.28430
# [20]	validation_0-rmse:10.15410	validation_1-rmse:9.97270
# [30]	validation_0-rmse:9.81910	validation_1-rmse:9.68125
# [40]	validation_0-rmse:9.50571	validation_1-rmse:9.40890
# [50]	validation_0-rmse:9.21286	validation_1-rmse:9.15473
# [60]	validation_0-rmse:8.93952	validation_1-rmse:8.91753
# [70]	validation_0-rmse:8.68464	validation_1-rmse:8.69605
# [80]	validation_0-rmse:8.44708	validation_1-rmse:8.48342
# [90]	validation_0-rmse:8.22562	validation_1-rmse:8.28514
# [100]	validation_0-rmse:8.01821	validation_1-rmse:8.10528
# [110]	validation_0-rmse:7.82532	validation_1-rmse:7.93878
# [120]	validation_0-rmse:7.64642	validation_1-rmse:7.78442
# [130]	validation_0-rmse:7.48036	validation_1-rmse:7.64178
# [140]	validation_0-rmse:7.32654	validation_1-rmse:7.51044
# [150]	validation_0-rmse:7.18403	validation_1-rmse:7.39044
# [160]	validation_0-rmse:7.05218	validation_1-rmse:7.27646
# [170]	validation_0-rmse:6.93019	validation_1-rmse:7.17183
# [180]	validation_0-rmse:6.81743	validation_1-rmse:7.07518
# [190]	validation_0-rmse:6.71324	validation_1-rmse:6.98583
# [200]	validation_0-rmse:6.61709	validation_1-rmse:6.90573
# [210]	validation_0-rmse:6.52823	validation_1-rmse:6.83355
# [220]	validation_0-rmse:6.44625	validation_1-rmse:6.76693
# [230]	validation_0-rmse:6.37062	validation_1-rmse:6.70683
# [240]	validation_0-rmse:6.29942	validation_1-rmse:6.64929
# [250]	validation_0-rmse:6.23291	validation_1-rmse:6.59608
# [260]	validation_0-rmse:6.17159	validation_1-rmse:6.54848
# [270]	validation_0-rmse:6.11436	validation_1-rmse:6.50348
# [280]	validation_0-rmse:6.06190	validation_1-rmse:6.46186
# [290]	validation_0-rmse:6.01312	validation_1-rmse:6.42359
# [300]	validation_0-rmse:5.96796	validation_1-rmse:6.38844
# [310]	validation_0-rmse:5.92661	validation_1-rmse:6.35475
# [320]	validation_0-rmse:5.88812	validation_1-rmse:6.32654
# [330]	validation_0-rmse:5.85281	validation_1-rmse:6.29745
# [340]	validation_0-rmse:5.82003	validation_1-rmse:6.27102
# [350]	validation_0-rmse:5.78938	validation_1-rmse:6.24626
# [360]	validation_0-rmse:5.76116	validation_1-rmse:6.22348
# [370]	validation_0-rmse:5.73515	validation_1-rmse:6.20205
# [380]	validation_0-rmse:5.71092	validation_1-rmse:6.18164
# [390]	validation_0-rmse:5.68843	validation_1-rmse:6.16363
# [400]	validation_0-rmse:5.66761	validation_1-rmse:6.14573
# [410]	validation_0-rmse:5.64811	validation_1-rmse:6.12973
# [420]	validation_0-rmse:5.62992	validation_1-rmse:6.11397
# [430]	validation_0-rmse:5.61287	validation_1-rmse:6.09879
# [440]	validation_0-rmse:5.59696	validation_1-rmse:6.08585
# [450]	validation_0-rmse:5.58213	validation_1-rmse:6.07285
# [460]	validation_0-rmse:5.56799	validation_1-rmse:6.06169
# [470]	validation_0-rmse:5.55467	validation_1-rmse:6.05002
# [480]	validation_0-rmse:5.54187	validation_1-rmse:6.03822
# [490]	validation_0-rmse:5.52958	validation_1-rmse:6.02713
# [500]	validation_0-rmse:5.51804	validation_1-rmse:6.01763
# [510]	validation_0-rmse:5.50689	validation_1-rmse:6.00804
# [520]	validation_0-rmse:5.49646	validation_1-rmse:5.99906
# [530]	validation_0-rmse:5.48656	validation_1-rmse:5.99047
# [540]	validation_0-rmse:5.47733	validation_1-rmse:5.98311
# [550]	validation_0-rmse:5.46841	validation_1-rmse:5.97587
# [560]	validation_0-rmse:5.45991	validation_1-rmse:5.96880
# [570]	validation_0-rmse:5.45168	validation_1-rmse:5.96090
# [580]	validation_0-rmse:5.44401	validation_1-rmse:5.95506
# [590]	validation_0-rmse:5.43649	validation_1-rmse:5.94780
# [600]	validation_0-rmse:5.42953	validation_1-rmse:5.94189
# [610]	validation_0-rmse:5.42269	validation_1-rmse:5.93781
# [620]	validation_0-rmse:5.41583	validation_1-rmse:5.93463
# [630]	validation_0-rmse:5.40945	validation_1-rmse:5.93186
# [640]	validation_0-rmse:5.40332	validation_1-rmse:5.92860
# [650]	validation_0-rmse:5.39733	validation_1-rmse:5.92536
# [660]	validation_0-rmse:5.39162	validation_1-rmse:5.92376
# [670]	validation_0-rmse:5.38638	validation_1-rmse:5.92189
# [680]	validation_0-rmse:5.38149	validation_1-rmse:5.91982
# [690]	validation_0-rmse:5.37656	validation_1-rmse:5.91778
# [700]	validation_0-rmse:5.37147	validation_1-rmse:5.91647
# [710]	validation_0-rmse:5.36530	validation_1-rmse:5.91551
# [720]	validation_0-rmse:5.35927	validation_1-rmse:5.91496
# [730]	validation_0-rmse:5.35369	validation_1-rmse:5.91388
# [740]	validation_0-rmse:5.34850	validation_1-rmse:5.91269
# [750]	validation_0-rmse:5.34386	validation_1-rmse:5.91134
# [760]	validation_0-rmse:5.33940	validation_1-rmse:5.91108
# [770]	validation_0-rmse:5.33528	validation_1-rmse:5.91114
# [780]	validation_0-rmse:5.33127	validation_1-rmse:5.91145
# [790]	validation_0-rmse:5.32597	validation_1-rmse:5.91206
# [800]	validation_0-rmse:5.31743	validation_1-rmse:5.91326
# [808]	validation_0-rmse:5.31154	validation_1-rmse:5.91399
# 8.546336651758923

# %%
param_grid = {
    'n_estimators': [100, 500, 1000],    # Number of trees in the forest
    'learning_rate': [0.01, 0.1, 0.2],   # Learning rate
    'max_depth': [3, 5, 7],               # Maximum depth of each tree
    'subsample': [0.8, 1.0],              # Subsample ratio of the training instances
    'colsample_bytree': [0.8, 1.0]        # Subsample ratio of columns when constructing each tree
}

# %%
import xgboost as xgb

# %%
xgb = xgb.XGBRegressor(random_state=42)
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(xgb, param_grid, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 4
#       2 from sklearn.model_selection import GridSearchCV
#       3 grid_search = GridSearchCV(xgb, param_grid, scoring='neg_mean_squared_error', cv=5)
# ----> 4 grid_search.fit(X_train, y_train)
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1572, in GridSearchCV._run_search(self, evaluate_candidates)
#    1570 def _run_search(self, evaluate_candidates):
#    1571     """Search all candidates in param_grid"""
# -> 1572     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:1108, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1105     obj = None
#    1107 model, metric, params = self._configure_fit(xgb_model, params)
# -> 1108 self._Booster = train(
#    1109     params,
#    1110     train_dmatrix,
#    1111     self.get_num_boosting_rounds(),
#    1112     evals=evals,
#    1113     early_stopping_rounds=self.early_stopping_rounds,
#    1114     evals_result=evals_result,
#    1115     obj=obj,
#    1116     custom_metric=metric,
#    1117     verbose_eval=verbose,
#    1118     xgb_model=model,
#    1119     callbacks=self.callbacks,
#    1120 )
#    1122 self._set_evaluation_result(evals_result)
#    1123 return self
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\telan\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
print("Best Hyperparameters:", grid_search.best_params_)
best_xgb = grid_search.best_estimator_
y_pred = best_xgb.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Test Root Mean Squared Error:", rmse)
# Out:
# Best Hyperparameters: {'colsample_bytree': 0.8, 'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Test Root Mean Squared Error: 6.089615455974572

# %%
test['Quantity Predictions'] = y_pred
test
# Out:
# C:\Users\telan\AppData\Local\Temp\ipykernel_17328\3726821739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Quantity Predictions'] = y_pred
#             datum  Year  Month  Hour  Weekday Name  Drug  Quantity  \
# 1825   01-01-2019  2019      1   276             5     0      0.00
# 1826   01-02-2019  2019      1   276             6     0      5.33
# 1827   01-03-2019  2019      1   276             4     0      4.33
# 1828   01-04-2019  2019      1   276             0     0      7.00
# 1829   01-05-2019  2019      1   276             2     0      8.01
# ...           ...   ...    ...   ...           ...   ...       ...
# 16843  10-04-2019  2019     10   276             0     7      1.00
# 16844  10-05-2019  2019     10   276             2     7      0.33
# 16845  10-06-2019  2019     10   276             3     7      4.20
# 16846  10-07-2019  2019     10   276             1     7      1.00
# 16847  10-08-2019  2019     10   190             5     7      0.00
#
#        Quantity Predictions
# 1825               4.578609
# 1826               4.905593
# 1827               4.616585
# 1828               5.424590
# 1829               5.555935
# ...                     ...
# 16843              3.118207
# 16844              3.901338
# 16845              4.444452
# 16846              3.483537
# 16847              3.579948
#
# [2248 rows x 8 columns]

# %%
def predict_sales(start_date,end_date,drug):
    dates = pd.date_range(start=start_date, end=end_date, freq='D')
    df_test = pd.DataFrame(index=dates)
    df_test['Year'] = df_test.index.year
    df_test['Month'] = df_test.index.month
    df_test['Weekday Name'] = df_test.index.weekday
    df_test['Drug'] = drug
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    df_test['Weekday Name'] = le.fit_transform(df_test['Weekday Name'])
    df_test['predicted_quantity'] = reg.predict(df_test)
    json_output = dataframe_to_json(df_test)

    return json_output

# %%
import json

def dataframe_to_json(df):
    """
    Convert a pandas DataFrame to a JSON string.
    
    Parameters:
    df (pandas.DataFrame): The DataFrame to convert.

    Returns:
    str: The JSON string representation of the DataFrame.
    """
    # Convert DataFrame to JSON
    json_output = df.to_json(orient='records')
    return json_output

# %%
predict_sales(start_date = '2024-12-01',end_date = '2024-12-31',drug = 4)
# Out:
# '[{"Year":2024,"Month":12,"Weekday Name":6,"Drug":4,"predicted_quantity":9.4719753265},{"Year":2024,"Month":12,"Weekday Name":0,"Drug":4,"predicted_quantity":9.2156124115},{"Year":2024,"Month":12,"Weekday Name":1,"Drug":4,"predicted_quantity":9.0754022598},{"Year":2024,"Month":12,"Weekday Name":2,"Drug":4,"predicted_quantity":8.0350408554},{"Year":2024,"Month":12,"Weekday Name":3,"Drug":4,"predicted_quantity":6.704864502},{"Year":2024,"Month":12,"Weekday Name":4,"Drug":4,"predicted_quantity":8.3833627701},{"Year":2024,"Month":12,"Weekday Name":5,"Drug":4,"predicted_quantity":8.9942455292},{"Year":2024,"Month":12,"Weekday Name":6,"Drug":4,"predicted_quantity":9.4719753265},{"Year":2024,"Month":12,"Weekday Name":0,"Drug":4,"predicted_quantity":9.2156124115},{"Year":2024,"Month":12,"Weekday Name":1,"Drug":4,"predicted_quantity":9.0754022598},{"Year":2024,"Month":12,"Weekday Name":2,"Drug":4,"predicted_quantity":8.0350408554},{"Year":2024,"Month":12,"Weekday Name":3,"Drug":4,"predicted_quantity":6.704864502},{"Year":2024,"Month":12,"Weekday Name":4,"Drug":4,"predicted_quantity":8.3833627701},{"Year":2024,"Month":12,"Weekday Name":5,"Drug":4,"predicted_quantity":8.9942455292},{"Year":2024,"Month":12,"Weekday Name":6,"Drug":4,"predicted_quantity":9.4719753265},{"Year":2024,"Month":12,"Weekday Name":0,"Drug":4,"predicted_quantity":9.2156124115},{"Year":2024,"Month":12,"Weekday Name":1,"Drug":4,"predicted_quantity":9.0754022598},{"Year":2024,"Month":12,"Weekday Name":2,"Drug":4,"predicted_quantity":8.0350408554},{"Year":2024,"Month":12,"Weekday Name":3,"Drug":4,"predicted_quantity":6.704864502},{"Year":2024,"Month":12,"Weekday Name":4,"Drug":4,"predicted_quantity":8.3833627701},{"Year":2024,"Month":12,"Weekday Name":5,"Drug":4,"predicted_quantity":8.9942455292},{"Year":2024,"Month":12,"Weekday Name":6,"Drug":4,"predicted_quantity":9.4719753265},{"Year":2024,"Month":12,"Weekday Name":0,"Drug":4,"predicted_quantity":9.2156124115},{"Year":2024,"Month":12,"Weekday Name":1,"Drug":4,"predicted_quantity":9.0754022598},{"Year":2024,"Month":12,"Weekday Name":2,"Drug":4,"predicted_quantity":8.0350408554},{"Year":2024,"Month":12,"Weekday Name":3,"Drug":4,"predicted_quantity":6.704864502},{"Year":2024,"Month":12,"Weekday Name":4,"Drug":4,"predicted_quantity":8.3833627701},{"Year":2024,"Month":12,"Weekday Name":5,"Drug":4,"predicted_quantity":8.9942455292},{"Year":2024,"Month":12,"Weekday Name":6,"Drug":4,"predicted_quantity":9.4719753265},{"Year":2024,"Month":12,"Weekday Name":0,"Drug":4,"predicted_quantity":9.2156124115},{"Year":2024,"Month":12,"Weekday Name":1,"Drug":4,"predicted_quantity":9.0754022598}]'

# %%
predict_sales(start_date = '2024-10-01',end_date = '2024-10-31',drug = 0)
# Out:
#             Year  Month  Weekday Name  Drug  predicted_quantity
# 2024-10-01  2024     10             1     0            4.855311
# 2024-10-02  2024     10             2     0            5.423892
# 2024-10-03  2024     10             3     0            5.631983
# 2024-10-04  2024     10             4     0            4.605959
# 2024-10-05  2024     10             5     0            4.701528
# 2024-10-06  2024     10             6     0            4.609930
# 2024-10-07  2024     10             0     0            4.566560
# 2024-10-08  2024     10             1     0            4.855311
# 2024-10-09  2024     10             2     0            5.423892
# 2024-10-10  2024     10             3     0            5.631983
# 2024-10-11  2024     10             4     0            4.605959
# 2024-10-12  2024     10             5     0            4.701528
# 2024-10-13  2024     10             6     0            4.609930
# 2024-10-14  2024     10             0     0            4.566560
# 2024-10-15  2024     10             1     0            4.855311
# 2024-10-16  2024     10             2     0            5.423892
# 2024-10-17  2024     10             3     0            5.631983
# 2024-10-18  2024     10             4     0            4.605959
# 2024-10-19  2024     10             5     0            4.701528
# 2024-10-20  2024     10             6     0            4.609930
# 2024-10-21  2024     10             0     0            4.566560
# 2024-10-22  2024     10             1     0            4.855311
# 2024-10-23  2024     10             2     0            5.423892
# 2024-10-24  2024     10             3     0            5.631983
# 2024-10-25  2024     10             4     0            4.605959
# 2024-10-26  2024     10             5     0            4.701528
# 2024-10-27  2024     10             6     0            4.609930
# 2024-10-28  2024     10             0     0            4.566560
# 2024-10-29  2024     10             1     0            4.855311
# 2024-10-30  2024     10             2     0            5.423892
# 2024-10-31  2024     10             3     0            5.631983
